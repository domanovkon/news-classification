# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd
from ipywidgets import Select, SelectMultiple, interactive,  Layout, Box, Label
df = pd.read_json('/kaggle/input/news-category-dataset/News_Category_Dataset_v2.json', lines = True)
df.head()
# df = pd.read_csv('123.csv', names=['description','true_category'])
# df.head()

encoder = LabelEncoder()
df['categoryEncoded'] = encoder.fit_transform(df['true_category'])
df.describe()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9016/2323948050.py in <module>
#       2 import pandas as pd
#       3 from ipywidgets import Select, SelectMultiple, interactive,  Layout, Box, Label
# ----> 4 df = pd.read_json('/kaggle/input/news-category-dataset/News_Category_Dataset_v2.json', lines = True)
#       5 df.head()
#       6 # df = pd.read_csv('123.csv', names=['description','true_category'])
#
# c:\users\domanov\appdata\local\programs\python\python39\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     197                 else:
#     198                     kwargs[new_arg_name] = new_arg_value
# --> 199             return func(*args, **kwargs)
#     200
#     201         return cast(F, wrapper)
#
# c:\users\domanov\appdata\local\programs\python\python39\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# c:\users\domanov\appdata\local\programs\python\python39\lib\site-packages\pandas\io\json\_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression, nrows, storage_options)
#     561
#     562     with json_reader:
# --> 563         return json_reader.read()
#     564
#     565
#
# c:\users\domanov\appdata\local\programs\python\python39\lib\site-packages\pandas\io\json\_json.py in read(self)
#     690                 data = ensure_str(self.data)
#     691                 data_lines = data.split("\n")
# --> 692                 obj = self._get_object_parser(self._combine_lines(data_lines))
#     693         else:
#     694             obj = self._get_object_parser(self.data)
#
# c:\users\domanov\appdata\local\programs\python\python39\lib\site-packages\pandas\io\json\_json.py in _get_object_parser(self, json)
#     714         obj = None
#     715         if typ == "frame":
# --> 716             obj = FrameParser(json, **kwargs).parse()
#     717
#     718         if typ == "series" or obj is None:
#
# c:\users\domanov\appdata\local\programs\python\python39\lib\site-packages\pandas\io\json\_json.py in parse(self)
#     829
#     830         else:
# --> 831             self._parse_no_numpy()
#     832
#     833         if self.obj is None:
#
# c:\users\domanov\appdata\local\programs\python\python39\lib\site-packages\pandas\io\json\_json.py in _parse_no_numpy(self)
#    1077         if orient == "columns":
#    1078             self.obj = DataFrame(
# -> 1079                 loads(json, precise_float=self.precise_float), dtype=None
#    1080             )
#    1081         elif orient == "split":
#
# ValueError: Expected object or value

# %%
#выбрать столбец, который будет отвечать за тип
# yselect = Select(
#         options=list(df.columns),
#         value=list(df.columns)[0],
#         description='Select file:',
#         disabled=False
#     )
yselect = "true_category"

# %%
# выбрать столбец, который будет отвечать за текст
# xselect = Select(
#         options=list(df.columns),
#         value=list(df.columns)[0],
#         description='Select file:',
#         disabled=False
#     )
# xselect = "description"

# %%
from matplotlib import pyplot as plt

#просто смотрим какие у нас есть лейблы
fig, ax = plt.subplots()
fig.suptitle("this is what we have", fontsize=12)
df[yselect].reset_index().groupby(yselect).count().sort_values(by=
       "index").plot(kind="barh", legend=False,
        ax=ax).grid(axis='x')
plt.show()
